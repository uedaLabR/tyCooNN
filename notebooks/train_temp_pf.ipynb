# %%
import os
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import training.Trainning as training
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
inputDir  = "/home/bhaskar/work/tyCooNNTest/trimpq/"
outputDir = "/home/bhaskar/work/tyCooNNTest/train_temp_pf/"
params    = "/home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml"

scheme = {'0': {'epoch':20, 'data_augment':0, 'dropoutRate':0.1, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 'done': True},
          '1': {'epoch':5, 'data_augment':0, 'dropoutRate':0.1, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 'done': False, 
                'apply_post_filter_to_train': True, 'post_threshold': 0.2}
         }

# %%
training.do_train_by_scheme(inputDir,outputDir,params,scheme)
# Out:
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history.png
# Previus output:  None
# Loading data from  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Evaluate
# Throughput:  100.0
# Accuracy  :  98.22121212121212
# Datapath: /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Doing scheme:  1
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  1
# ...
