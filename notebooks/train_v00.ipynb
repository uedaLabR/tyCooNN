# %% [markdown]
# Here we train our network using generated parquet files

# %%
import os
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import training.Trainning as training
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
inputDir  = "/home/bhaskar/work/tyCooNNTest/trimpq/"
outputDir = "/home/bhaskar/work/tyCooNNTest/train_temp_default/"
params    = "/home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml"

scheme = {'0': {'epoch':50, 'data_augment':0, 'dropoutRate':0.2, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': False, 'load_with_shuffle': True},
          '1': {'epoch':20, 'data_augment':3, 'dropoutRate':0.2, 'learning_rate':   0.0001,
                'batch_size':128, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': False, 'load_with_shuffle': True},
         }

# %%
training.do_train_by_scheme(inputDir,outputDir,params,scheme)
# Out:
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_default//BestWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_default//AllWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_default//history.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_default//history.png
# Previus output:  None
# Loading data with shuffle
# /home/bhaskar/work/tyCooNNTest/trimpq/gln2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/met.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/fmet.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gln1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/lys.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/asn.pq
# ...

# %%
historyPath = output + "/history.csv"
h = pd.read_csv(historyPath)
h

# %%
plt.plot(h['accuracy'],'b-'); plt.plot(h['val_accuracy'],'k-'); plt.show();

# %%
plt.plot(h['loss'],'b-'); plt.plot(h['val_loss'],'k-'); plt.show();

# %%
np.max(h['val_accuracy']),np.argmax(h['val_accuracy'])
