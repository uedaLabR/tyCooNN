# %%
import os
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import training.Trainning as training
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
inputDir  = "/home/bhaskar/work/tyCooNNTest/trimpq/"
outputDir = "/home/bhaskar/work/tyCooNNTest/train_temp_pf/"
params    = "/home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml"

scheme = {'0': {'epoch':20, 'data_augment':0, 'dropoutRate':0.2, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False, 'done': True},
          '1': {'epoch':20, 'data_augment':3, 'dropoutRate':0.2, 'learning_rate':   0.0001,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False},
          '2': {'epoch':20, 'data_augment':5, 'dropoutRate':0.2, 'learning_rate':   0.0001,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False}
         }

# %%
training.do_train_by_scheme(inputDir,outputDir,params,scheme)
