# %%
(((515700 * 102)/1000.0)/3600)/18

# %%
(((1750 * 2 * 100 * 102)/1000.0)/3600)/12

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
plt.rcParams['font.family'] = 'Times New Roman'

# %%
import matplotlib
matplotlib.font_manager._rebuild()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_95962/3305943187.py in <module>
#       1 import matplotlib
# ----> 2 matplotlib.font_manager._rebuild()
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'

# %%
import matplotlib as mpl

# %%
print(mpl.font_manager.get_cachedir())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_95962/2766521006.py in <module>
# ----> 1 print(mpl.font_manager.get_cachedir())
#
# AttributeError: module 'matplotlib.font_manager' has no attribute 'get_cachedir'

# %%
print(matplotlib.matplotlib_fname())
# Out:
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
