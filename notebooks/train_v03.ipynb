# %%
import os
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import training.Trainning as training
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
inputDir  = "/home/bhaskar/work/tyCooNNTest/trimpq/"
outputDir = "/home/bhaskar/work/tyCooNNTest/train_temp2/"
params    = "/home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml"

scheme = {'0': {'epoch':20, 'data_augment':0, 'dropoutRate':0.1, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2},
          '1': {'epoch':20, 'data_augment':3, 'dropoutRate':0.05, 'learning_rate': 0.00008,
                'batch_size':128, 'limit':18000, 'unit':1000, 'split':0.2},
          '2': {'epoch':20, 'data_augment':4, 'dropoutRate':0.05, 'learning_rate': 0.00008,
                'batch_size':128, 'limit':18000, 'unit':1000, 'split':0.2}
         }

# %%
training.do_train_by_scheme(inputDir,outputDir,params,scheme)
# Out:
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//AllWt.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history.png
# Previus output:  None
# Loading data
# /home/bhaskar/work/tyCooNNTest/trimpq/gln2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/met.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/fmet.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gln1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/lys.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/asn.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/tyr.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/his.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val2b.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ala2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/cys.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/phe.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/sec.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/asp.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val2a.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ala1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/trp.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ile1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/glu.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ile2.pq
# Number of classes:  44
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Loaded input data in /home/bhaskar/work/tyCooNNTest/train_temp2//data.pkl
# Setting checkpointers
# Start fitting
# test_x shape: (132000, 8192, 1)
# test_y shape: (132000, 44)
# train_x shape: (660000, 8192, 1)
# train_y shape: (660000, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2683/  2683, loss 0.844799 accuracy 85.55 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 91.71 Loss 0.559836
# Training statistics   at Epoch 0: Accuracy 85.55 Loss 0.844799
# Time taken: 417 sec, Time/batch: 155 ms, Time remaining to train: 8340 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2683/  2683, loss 0.372355 accuracy 96.08 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 95.65 Loss 0.338446
# Training statistics   at Epoch 1: Accuracy 96.08 Loss 0.372355
# Time taken: 371 sec, Time/batch: 138 ms, Time remaining to train: 7049 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2683/  2683, loss 0.258837 accuracy 97.69 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.46 Loss 0.252816
# Training statistics   at Epoch 2: Accuracy 97.69 Loss 0.258837
# Time taken: 369 sec, Time/batch: 137 ms, Time remaining to train: 6642 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2683/  2683, loss 0.228753 accuracy 97.86 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.69 Loss 0.226494
# Training statistics   at Epoch 3: Accuracy 97.86 Loss 0.228753
# Time taken: 369 sec, Time/batch: 137 ms, Time remaining to train: 6273 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2683/  2683, loss 0.206906 accuracy 97.97 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.82 Loss 0.208658
# Training statistics   at Epoch 4: Accuracy 97.97 Loss 0.206906
# Time taken: 367 sec, Time/batch: 136 ms, Time remaining to train: 5872 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2683/  2683, loss 0.189603 accuracy 98.04 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.64 Loss 0.203718
# Training statistics   at Epoch 5: Accuracy 98.04 Loss 0.189603
# Time taken: 366 sec, Time/batch: 136 ms, Time remaining to train: 5490 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2683/  2683, loss 0.169210 accuracy 98.30 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 98.09 Loss 0.177721
# Training statistics   at Epoch 6: Accuracy 98.30 Loss 0.169210
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 5096 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2683/  2683, loss 0.161521 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.04 Loss 0.176384
# Training statistics   at Epoch 7: Accuracy 98.35 Loss 0.161521
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 4732 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2683/  2683, loss 0.154941 accuracy 98.37 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 97.91 Loss 0.177225
# Training statistics   at Epoch 8: Accuracy 98.37 Loss 0.154941
# Time taken: 365 sec, Time/batch: 136 ms, Time remaining to train: 4380 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2683/  2683, loss 0.149054 accuracy 98.41 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 97.96 Loss 0.169652
# Training statistics   at Epoch 9: Accuracy 98.41 Loss 0.149054
# Time taken: 365 sec, Time/batch: 136 ms, Time remaining to train: 4015 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2683/  2683, loss 0.143966 accuracy 98.44 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 98.22 Loss 0.158174
# Training statistics   at Epoch 10: Accuracy 98.44 Loss 0.143966
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 3640 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2683/  2683, loss 0.139394 accuracy 98.45 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 97.91 Loss 0.164773
# Training statistics   at Epoch 11: Accuracy 98.45 Loss 0.139394
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 3276 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2683/  2683, loss 0.134960 accuracy 98.47 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.16 Loss 0.154847
# Training statistics   at Epoch 12: Accuracy 98.47 Loss 0.134960
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 2912 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2683/  2683, loss 0.130874 accuracy 98.49 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.07 Loss 0.155672
# Training statistics   at Epoch 13: Accuracy 98.49 Loss 0.130874
# Time taken: 365 sec, Time/batch: 136 ms, Time remaining to train: 2555 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2683/  2683, loss 0.127442 accuracy 98.50 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.08 Loss 0.153898
# Training statistics   at Epoch 14: Accuracy 98.50 Loss 0.127442
# Time taken: 366 sec, Time/batch: 136 ms, Time remaining to train: 2196 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2683/  2683, loss 0.123903 accuracy 98.52 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.19 Loss 0.147354
# Training statistics   at Epoch 15: Accuracy 98.52 Loss 0.123903
# Time taken: 365 sec, Time/batch: 136 ms, Time remaining to train: 1825 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2683/  2683, loss 0.120858 accuracy 98.53 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 97.87 Loss 0.157179
# Training statistics   at Epoch 16: Accuracy 98.53 Loss 0.120858
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 1456 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2683/  2683, loss 0.117725 accuracy 98.56 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.12 Loss 0.148649
# Training statistics   at Epoch 17: Accuracy 98.56 Loss 0.117725
# Time taken: 367 sec, Time/batch: 136 ms, Time remaining to train: 1101 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2683/  2683, loss 0.115195 accuracy 98.57 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.18 Loss 0.144268
# Training statistics   at Epoch 18: Accuracy 98.57 Loss 0.115195
# Time taken: 364 sec, Time/batch: 135 ms, Time remaining to train: 728 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2683/  2683, loss 0.112467 accuracy 98.58 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.03 Loss 0.149245
# Training statistics   at Epoch 19: Accuracy 98.58 Loss 0.112467
# Time taken: 365 sec, Time/batch: 136 ms, Time remaining to train: 365 sec
# Validation statistics after training: Accuracy 98.03 Loss 0.149245
# Training statistics after training: Accuracy 98.58 Loss 0.112467
# Outputting
# Datapath: /home/bhaskar/work/tyCooNNTest/train_temp2//data.pkl
# Doing scheme:  1
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  1
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt_v1.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//AllWt_v1.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//AllWt.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v1.csv
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//history.csv
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v1.png
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//history.png
# Loading data from  /home/bhaskar/work/tyCooNNTest/train_temp2//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Loaded pretrained model weights from /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt.h5
# Setting checkpointers
# Start fitting
# test_x shape: (132000, 8192, 1)
# test_y shape: (132000, 44)
# train_x shape: (660000, 8192, 1)
# train_y shape: (660000, 44)
# N: 660000 Na: 1980000 NB: 15469
# fitting with augmentation with 15469 batches
# ## Dummy ##
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# ## Dummy End ##
# Augmentation Time  :  152.0
# Predicted test time:  18.0
#
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 21/60
# Batch  15469/ 15469, loss 0.133742 accuracy 98.59 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 98.29 Loss 0.152783
# Training statistics   at Epoch 0: Accuracy 98.59 Loss 0.133742
# Time taken: 1842 sec, Time/batch: 119 ms, Time remaining to train: 36840 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 2/20 of training, Total Epoch: 22/60
# Batch  15469/ 15469, loss 0.130306 accuracy 98.63 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 98.29 Loss 0.152315
# Training statistics   at Epoch 1: Accuracy 98.63 Loss 0.130306
# Time taken: 1785 sec, Time/batch: 115 ms, Time remaining to train: 33915 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 3/20 of training, Total Epoch: 23/60
# Batch  15469/ 15469, loss 0.128845 accuracy 98.64 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 98.30 Loss 0.150798
# Training statistics   at Epoch 2: Accuracy 98.64 Loss 0.128845
# Time taken: 1810 sec, Time/batch: 117 ms, Time remaining to train: 32580 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 4/20 of training, Total Epoch: 24/60
# Batch  15469/ 15469, loss 0.127588 accuracy 98.65 ETA: 0          secc
# Validation statistics at Epoch 3: Accuracy 98.29 Loss 0.150936
# Training statistics   at Epoch 3: Accuracy 98.65 Loss 0.127588
# Time taken: 1821 sec, Time/batch: 117 ms, Time remaining to train: 30957 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 5/20 of training, Total Epoch: 25/60
# Batch  15469/ 15469, loss 0.126431 accuracy 98.65 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 98.29 Loss 0.150370
# Training statistics   at Epoch 4: Accuracy 98.65 Loss 0.126431
# Time taken: 1832 sec, Time/batch: 118 ms, Time remaining to train: 29312 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 6/20 of training, Total Epoch: 26/60
# Batch  15469/ 15469, loss 0.125125 accuracy 98.66 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 98.30 Loss 0.149285
# Training statistics   at Epoch 5: Accuracy 98.66 Loss 0.125125
# Time taken: 1829 sec, Time/batch: 118 ms, Time remaining to train: 27435 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 7/20 of training, Total Epoch: 27/60
# Batch  15469/ 15469, loss 0.124195 accuracy 98.66 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 98.30 Loss 0.148736
# Training statistics   at Epoch 6: Accuracy 98.66 Loss 0.124195
# Time taken: 1836 sec, Time/batch: 118 ms, Time remaining to train: 25704 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 8/20 of training, Total Epoch: 28/60
# Batch  15469/ 15469, loss 0.123107 accuracy 98.66 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.29 Loss 0.148439
# Training statistics   at Epoch 7: Accuracy 98.66 Loss 0.123107
# Time taken: 1841 sec, Time/batch: 119 ms, Time remaining to train: 23933 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 9/20 of training, Total Epoch: 29/60
# Batch  15469/ 15469, loss 0.121822 accuracy 98.68 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 98.30 Loss 0.147638
# Training statistics   at Epoch 8: Accuracy 98.68 Loss 0.121822
# Time taken: 1898 sec, Time/batch: 122 ms, Time remaining to train: 22776 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 10/20 of training, Total Epoch: 30/60
# Batch  15469/ 15469, loss 0.120901 accuracy 98.68 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 98.29 Loss 0.147604
# Training statistics   at Epoch 9: Accuracy 98.68 Loss 0.120901
# Time taken: 1825 sec, Time/batch: 117 ms, Time remaining to train: 20075 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 11/20 of training, Total Epoch: 31/60
# Batch  15469/ 15469, loss 0.120219 accuracy 98.68 ETA: 0          secc
# Validation statistics at Epoch 10: Accuracy 98.27 Loss 0.147388
# Training statistics   at Epoch 10: Accuracy 98.68 Loss 0.120219
# Time taken: 1821 sec, Time/batch: 117 ms, Time remaining to train: 18210 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 12/20 of training, Total Epoch: 32/60
# Batch  15469/ 15469, loss 0.118907 accuracy 98.69 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.29 Loss 0.146619
# Training statistics   at Epoch 11: Accuracy 98.69 Loss 0.118907
# Time taken: 1815 sec, Time/batch: 117 ms, Time remaining to train: 16335 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 13/20 of training, Total Epoch: 33/60
# Batch  15469/ 15469, loss 0.118151 accuracy 98.69 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.28 Loss 0.146108
# Training statistics   at Epoch 12: Accuracy 98.69 Loss 0.118151
# Time taken: 1805 sec, Time/batch: 116 ms, Time remaining to train: 14440 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 14/20 of training, Total Epoch: 34/60
# Batch  15469/ 15469, loss 0.117264 accuracy 98.70 ETA: 0          secc
# Validation statistics at Epoch 13: Accuracy 98.27 Loss 0.145619
# Training statistics   at Epoch 13: Accuracy 98.70 Loss 0.117264
# Time taken: 1828 sec, Time/batch: 118 ms, Time remaining to train: 12796 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 15/20 of training, Total Epoch: 35/60
# Batch  15469/ 15469, loss 0.116339 accuracy 98.70 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.27 Loss 0.145214
# Training statistics   at Epoch 14: Accuracy 98.70 Loss 0.116339
# Time taken: 1851 sec, Time/batch: 119 ms, Time remaining to train: 11106 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 16/20 of training, Total Epoch: 36/60
# Batch  15469/ 15469, loss 0.115389 accuracy 98.71 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.28 Loss 0.144882
# Training statistics   at Epoch 15: Accuracy 98.71 Loss 0.115389
# Time taken: 1834 sec, Time/batch: 118 ms, Time remaining to train: 9170 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 17/20 of training, Total Epoch: 37/60
# Batch  15469/ 15469, loss 0.114640 accuracy 98.71 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.27 Loss 0.144914
# Training statistics   at Epoch 16: Accuracy 98.71 Loss 0.114640
# Time taken: 1853 sec, Time/batch: 119 ms, Time remaining to train: 7412 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 18/20 of training, Total Epoch: 38/60
# Batch  15469/ 15469, loss 0.113885 accuracy 98.72 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.29 Loss 0.143992
# Training statistics   at Epoch 17: Accuracy 98.72 Loss 0.113885
# Time taken: 1831 sec, Time/batch: 118 ms, Time remaining to train: 5493 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 19/20 of training, Total Epoch: 39/60
# Batch  15469/ 15469, loss 0.113003 accuracy 98.72 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.23 Loss 0.144697
# Training statistics   at Epoch 18: Accuracy 98.72 Loss 0.113003
# Time taken: 1822 sec, Time/batch: 117 ms, Time remaining to train: 3644 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████Start epoch 20/20 of training, Total Epoch: 40/60
#  end
# end merge
# Batch  15469/ 15469, loss 0.112170 accuracy 98.72 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.27 Loss 0.143189
# Training statistics   at Epoch 19: Accuracy 98.72 Loss 0.112170
# Time taken: 1819 sec, Time/batch: 117 ms, Time remaining to train: 1819 sec
# Validation statistics after training: Accuracy 98.27 Loss 0.143189
# Training statistics after training: Accuracy 98.72 Loss 0.112170
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Outputting
# Doing scheme:  2
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  2
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt_v2.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt_v1.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//AllWt_v2.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//AllWt_v1.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v2.csv
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v1.csv
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v2.png
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp2//history_v1.png
# Loading data from  /home/bhaskar/work/tyCooNNTest/train_temp2//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Loaded pretrained model weights from /home/bhaskar/work/tyCooNNTest/train_temp2//BestWt_v1.h5
# Setting checkpointers
# Start fitting
# test_x shape: (132000, 8192, 1)
# test_y shape: (132000, 44)
# train_x shape: (660000, 8192, 1)
# train_y shape: (660000, 44)
# N: 660000 Na: 2640000 NB: 20625
# fitting with augmentation with 20625 batches
# ## Dummy ##
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# ## Dummy End ##
# Augmentation Time  :  207.0
# Predicted test time:  23.0
#
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 21/60
# Batch  20625/ 20625, loss 0.127934 accuracy 98.63 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 98.28 Loss 0.150819
# Training statistics   at Epoch 0: Accuracy 98.63 Loss 0.127934
# Time taken: 2445 sec, Time/batch: 118 ms, Time remaining to train: 48900 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 2/20 of training, Total Epoch: 22/60
# Batch  20625/ 20625, loss 0.125039 accuracy 98.65 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 98.29 Loss 0.148642
# Training statistics   at Epoch 1: Accuracy 98.65 Loss 0.125039
# Time taken: 2390 sec, Time/batch: 115 ms, Time remaining to train: 45410 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 3/20 of training, Total Epoch: 23/60
# Batch  20625/ 20625, loss 0.123552 accuracy 98.66 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 98.27 Loss 0.148650
# Training statistics   at Epoch 2: Accuracy 98.66 Loss 0.123552
# Time taken: 2386 sec, Time/batch: 115 ms, Time remaining to train: 42948 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 4/20 of training, Total Epoch: 24/60
# Batch  20625/ 20625, loss 0.122155 accuracy 98.67 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 98.30 Loss 0.147422
# Training statistics   at Epoch 3: Accuracy 98.67 Loss 0.122155
# Time taken: 2405 sec, Time/batch: 116 ms, Time remaining to train: 40885 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 5/20 of training, Total Epoch: 25/60
# Batch  20625/ 20625, loss 0.120876 accuracy 98.67 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 98.29 Loss 0.146915
# Training statistics   at Epoch 4: Accuracy 98.67 Loss 0.120876
# Time taken: 2391 sec, Time/batch: 115 ms, Time remaining to train: 38256 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# Start epoch 6/20 of training, Total Epoch: 26/60
# end merge
# Batch  20625/ 20625, loss 0.119597 accuracy 98.68 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 98.29 Loss 0.146018
# Training statistics   at Epoch 5: Accuracy 98.68 Loss 0.119597
# Time taken: 2401 sec, Time/batch: 116 ms, Time remaining to train: 36015 sec
# n_cores 10
# data augmentation: Start ███████████████████████████████████████Start epoch 7/20 of training, Total Epoch: 27/60
# ███████████ end
# end merge
# Batch  20625/ 20625, loss 0.118237 accuracy 98.68 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 98.28 Loss 0.145600
# Training statistics   at Epoch 6: Accuracy 98.68 Loss 0.118237
# Time taken: 2474 sec, Time/batch: 119 ms, Time remaining to train: 34636 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 8/20 of training, Total Epoch: 28/60
# Batch  20625/ 20625, loss 0.116999 accuracy 98.69 ETA: 0          secc
# Validation statistics at Epoch 7: Accuracy 98.25 Loss 0.145877
# Training statistics   at Epoch 7: Accuracy 98.69 Loss 0.116999
# Time taken: 2383 sec, Time/batch: 115 ms, Time remaining to train: 30979 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Start epoch 9/20 of training, Total Epoch: 29/60
# Batch  20625/ 20625, loss 0.115955 accuracy 98.70 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 98.27 Loss 0.144756
# Training statistics   at Epoch 8: Accuracy 98.70 Loss 0.115955
# Time taken: 2391 sec, Time/batch: 115 ms, Time remaining to train: 28692 sec
# n_cores 10
# data augmentation: Start █████████████████████████████████████████████████Start epoch 10/20 of training, Total Epoch: 30/60
# █ end
# end merge
# Batch  20625/ 20625, loss 0.114756 accuracy 98.70 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 98.29 Loss 0.144099
# Training statistics   at Epoch 9: Accuracy 98.70 Loss 0.114756
# Time taken: 2479 sec, Time/batch: 120 ms, Time remaining to train: 27269 sec
# n_cores 10
# data augmentation: Start ████████████████████████████████████████████████Start epoch 11/20 of training, Total Epoch: 31/60
# ██ end
# end merge
# Batch  20625/ 20625, loss 0.113726 accuracy 98.71 ETA: 0          secc
# Validation statistics at Epoch 10: Accuracy 98.27 Loss 0.143388
# Training statistics   at Epoch 10: Accuracy 98.71 Loss 0.113726
# Time taken: 2496 sec, Time/batch: 121 ms, Time remaining to train: 24960 sec
# n_cores 10
# data augmentation: Start ███████████████████████████████████████████Start epoch 12/20 of training, Total Epoch: 32/60
# ███████ end
# end merge
# Batch  20625/ 20625, loss 0.112557 accuracy 98.71 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.25 Loss 0.143650
# Training statistics   at Epoch 11: Accuracy 98.71 Loss 0.112557
# Time taken: 2467 sec, Time/batch: 119 ms, Time remaining to train: 22203 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████Start epoch 13/20 of training, Total Epoch: 33/60
# ████████████ end
# end merge
# Batch  20625/ 20625, loss 0.111591 accuracy 98.72 ETA: 0          secc
# Validation statistics at Epoch 12: Accuracy 98.28 Loss 0.143018
# Training statistics   at Epoch 12: Accuracy 98.72 Loss 0.111591
# Time taken: 2557 sec, Time/batch: 123 ms, Time remaining to train: 20456 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████Start epoch 14/20 of training, Total Epoch: 34/60
# ████████████████ end
# end merge
# Batch  20625/ 20625, loss 0.110475 accuracy 98.72 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.26 Loss 0.142161
# Training statistics   at Epoch 13: Accuracy 98.72 Loss 0.110475
# Time taken: 2553 sec, Time/batch: 123 ms, Time remaining to train: 17871 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████Start epoch 15/20 of training, Total Epoch: 35/60████████████████ end
# end merge
# Batch  20625/ 20625, loss 0.109564 accuracy 98.73 ETA: 0          secc
# Validation statistics at Epoch 14: Accuracy 98.25 Loss 0.142184
# Training statistics   at Epoch 14: Accuracy 98.73 Loss 0.109564
# Time taken: 2620 sec, Time/batch: 127 ms, Time remaining to train: 15720 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████Start epoch 16/20 of training, Total Epoch: 36/60
# ████████████████ end
# end merge
# Batch  20625/ 20625, loss 0.108557 accuracy 98.73 ETA: 0          secc
# Validation statistics at Epoch 15: Accuracy 98.25 Loss 0.142269
# Training statistics   at Epoch 15: Accuracy 98.73 Loss 0.108557
# Time taken: 2615 sec, Time/batch: 126 ms, Time remaining to train: 13075 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████████Start epoch 17/20 of training, Total Epoch: 37/60
# ████████████ end
# end merge
# Batch  20625/ 20625, loss 0.107492 accuracy 98.74 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.23 Loss 0.141983
# Training statistics   at Epoch 16: Accuracy 98.74 Loss 0.107492
# Time taken: 2548 sec, Time/batch: 123 ms, Time remaining to train: 10192 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████Start epoch 18/20 of training, Total Epoch: 38/60
# ████████████████ end
# end merge
# Batch  20625/ 20625, loss 0.106577 accuracy 98.75 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.24 Loss 0.141473
# Training statistics   at Epoch 17: Accuracy 98.75 Loss 0.106577
# Time taken: 2591 sec, Time/batch: 125 ms, Time remaining to train: 7773 sec
# n_cores 10
# data augmentation: Start ██████████████████████████████████Start epoch 19/20 of training, Total Epoch: 39/60
# ████████████████ end
# end merge
# Batch  20625/ 20625, loss 0.105709 accuracy 98.75 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.23 Loss 0.141233
# Training statistics   at Epoch 18: Accuracy 98.75 Loss 0.105709
# Time taken: 2548 sec, Time/batch: 123 ms, Time remaining to train: 5096 sec
# n_cores 10
# data augmentation: Start █████████████████████████████████████████Start epoch 20/20 of training, Total Epoch: 40/60
# █████████ end
# end merge
# Batch  20625/ 20625, loss 0.104693 accuracy 98.76 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.23 Loss 0.141150
# Training statistics   at Epoch 19: Accuracy 98.76 Loss 0.104693
# Time taken: 2528 sec, Time/batch: 122 ms, Time remaining to train: 2528 sec
# Validation statistics after training: Accuracy 98.23 Loss 0.141150
# Training statistics after training: Accuracy 98.76 Loss 0.104693
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# Outputting
