# %%
import os
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import training.Trainning as training
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
inputDir  = "/home/bhaskar/work/tyCooNNTest/trimpq/"
outputDir = "/home/bhaskar/work/tyCooNNTest/train_temp_pf/"
params    = "/home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml"

scheme = {'0': {'epoch':20, 'data_augment':0, 'dropoutRate':0.2, 'learning_rate':   0.0008,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False},
          '1': {'epoch':20, 'data_augment':3, 'dropoutRate':0.2, 'learning_rate':   0.0001,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False},
          '2': {'epoch':20, 'data_augment':5, 'dropoutRate':0.2, 'learning_rate':   0.0001,
                'batch_size':246, 'limit':18000, 'unit':1000, 'split':0.2, 
                'cross_fold': True, 'load_with_shuffle': False}
         }

# %%
training.do_train_by_scheme(inputDir,outputDir,params,scheme)
# Out:
# Training for fold:  0
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k0.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k0.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k0.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k0.png
# Previus output:  None
# Loading data for ensemble learning
# /home/bhaskar/work/tyCooNNTest/trimpq/gln2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/met.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/fmet.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gln1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/lys.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/asn.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/tyr.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ser1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/arg3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/his.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val2b.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ala2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/cys.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/phe.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/pro1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/sec.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/asp.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/gly3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/val2a.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ala1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/trp.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ile1.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu5.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/glu.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr3.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/thr2.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/leu4.pq
# /home/bhaskar/work/tyCooNNTest/trimpq/ile2.pq
# Number of classes:  44
# Number of sample:  792000
# Loaded input data is saved in /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2576/  2576, loss 0.868456 accuracy 84.94 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 92.63 Loss 0.532204
# Training statistics   at Epoch 0: Accuracy 84.94 Loss 0.868456
# Time taken: 400 sec, Time/batch: 155 ms, Time remaining to train: 8000 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2576/  2576, loss 0.390979 accuracy 95.71 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 95.84 Loss 0.346182
# Training statistics   at Epoch 1: Accuracy 95.71 Loss 0.390979
# Time taken: 364 sec, Time/batch: 141 ms, Time remaining to train: 6916 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2576/  2576, loss 0.276894 accuracy 97.47 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.75 Loss 0.256791
# Training statistics   at Epoch 2: Accuracy 97.47 Loss 0.276894
# Time taken: 361 sec, Time/batch: 140 ms, Time remaining to train: 6498 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2576/  2576, loss 0.247298 accuracy 97.64 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.46 Loss 0.247658
# Training statistics   at Epoch 3: Accuracy 97.64 Loss 0.247298
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 6052 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2576/  2576, loss 0.223732 accuracy 97.78 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.51 Loss 0.229373
# Training statistics   at Epoch 4: Accuracy 97.78 Loss 0.223732
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 5728 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2576/  2576, loss 0.205865 accuracy 97.87 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.42 Loss 0.217584
# Training statistics   at Epoch 5: Accuracy 97.87 Loss 0.205865
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 5340 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2576/  2576, loss 0.186259 accuracy 98.11 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 97.98 Loss 0.193437
# Training statistics   at Epoch 6: Accuracy 98.11 Loss 0.186259
# Time taken: 357 sec, Time/batch: 138 ms, Time remaining to train: 4998 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2576/  2576, loss 0.177784 accuracy 98.16 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.15 Loss 0.181563
# Training statistics   at Epoch 7: Accuracy 98.16 Loss 0.177784
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 4654 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2576/  2576, loss 0.170985 accuracy 98.21 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 98.03 Loss 0.180727
# Training statistics   at Epoch 8: Accuracy 98.21 Loss 0.170985
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 4296 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2576/  2576, loss 0.164673 accuracy 98.23 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 98.13 Loss 0.172245
# Training statistics   at Epoch 9: Accuracy 98.23 Loss 0.164673
# Time taken: 357 sec, Time/batch: 138 ms, Time remaining to train: 3927 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2576/  2576, loss 0.159174 accuracy 98.26 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 98.05 Loss 0.172833
# Training statistics   at Epoch 10: Accuracy 98.26 Loss 0.159174
# Time taken: 354 sec, Time/batch: 137 ms, Time remaining to train: 3540 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2576/  2576, loss 0.154116 accuracy 98.29 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.12 Loss 0.167107
# Training statistics   at Epoch 11: Accuracy 98.29 Loss 0.154116
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 3204 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2576/  2576, loss 0.150139 accuracy 98.29 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.15 Loss 0.163633
# Training statistics   at Epoch 12: Accuracy 98.29 Loss 0.150139
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 2848 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2576/  2576, loss 0.145693 accuracy 98.32 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.13 Loss 0.160425
# Training statistics   at Epoch 13: Accuracy 98.32 Loss 0.145693
# Time taken: 354 sec, Time/batch: 137 ms, Time remaining to train: 2478 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2576/  2576, loss 0.141696 accuracy 98.34 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.19 Loss 0.156733
# Training statistics   at Epoch 14: Accuracy 98.34 Loss 0.141696
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 2136 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2576/  2576, loss 0.137912 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.06 Loss 0.156743
# Training statistics   at Epoch 15: Accuracy 98.35 Loss 0.137912
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 1760 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2576/  2576, loss 0.135228 accuracy 98.38 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.07 Loss 0.154333
# Training statistics   at Epoch 16: Accuracy 98.38 Loss 0.135228
# Time taken: 355 sec, Time/batch: 137 ms, Time remaining to train: 1420 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2576/  2576, loss 0.131401 accuracy 98.40 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.16 Loss 0.150410
# Training statistics   at Epoch 17: Accuracy 98.40 Loss 0.131401
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 1059 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2576/  2576, loss 0.128628 accuracy 98.39 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.09 Loss 0.149918
# Training statistics   at Epoch 18: Accuracy 98.39 Loss 0.128628
# Time taken: 357 sec, Time/batch: 138 ms, Time remaining to train: 714 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2576/  2576, loss 0.125485 accuracy 98.44 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.16 Loss 0.146604
# Training statistics   at Epoch 19: Accuracy 98.44 Loss 0.125485
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 353 sec
# Validation statistics after training: Accuracy 98.16 Loss 0.146604
# Training statistics after training: Accuracy 98.44 Loss 0.125485
# Outputting
# Evaluate
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Throughput:  100.0
# Accuracy  :  98.15845959595958
# Training for fold:  1
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k1.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k1.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k1.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k1.png
# Previus output:  None
# Found data for loading at  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2576/  2576, loss 0.899328 accuracy 84.12 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 89.90 Loss 0.619331
# Training statistics   at Epoch 0: Accuracy 84.12 Loss 0.899328
# Time taken: 386 sec, Time/batch: 149 ms, Time remaining to train: 7720 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2576/  2576, loss 0.392492 accuracy 95.66 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 95.11 Loss 0.369729
# Training statistics   at Epoch 1: Accuracy 95.66 Loss 0.392492
# Time taken: 354 sec, Time/batch: 137 ms, Time remaining to train: 6726 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2576/  2576, loss 0.277897 accuracy 97.42 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.22 Loss 0.276515
# Training statistics   at Epoch 2: Accuracy 97.42 Loss 0.277897
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 6354 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2576/  2576, loss 0.247066 accuracy 97.62 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.45 Loss 0.246236
# Training statistics   at Epoch 3: Accuracy 97.62 Loss 0.247066
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 5984 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2576/  2576, loss 0.223471 accuracy 97.76 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.34 Loss 0.234865
# Training statistics   at Epoch 4: Accuracy 97.76 Loss 0.223471
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 5632 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2576/  2576, loss 0.205284 accuracy 97.86 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.64 Loss 0.210925
# Training statistics   at Epoch 5: Accuracy 97.86 Loss 0.205284
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 5280 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2576/  2576, loss 0.185068 accuracy 98.13 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 97.97 Loss 0.193771
# Training statistics   at Epoch 6: Accuracy 98.13 Loss 0.185068
# Time taken: 355 sec, Time/batch: 137 ms, Time remaining to train: 4970 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2576/  2576, loss 0.176791 accuracy 98.17 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.06 Loss 0.183492
# Training statistics   at Epoch 7: Accuracy 98.17 Loss 0.176791
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 4576 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2576/  2576, loss 0.169661 accuracy 98.19 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 97.92 Loss 0.183708
# Training statistics   at Epoch 8: Accuracy 98.19 Loss 0.169661
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 4200 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2576/  2576, loss 0.163966 accuracy 98.22 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 97.91 Loss 0.180634
# Training statistics   at Epoch 9: Accuracy 98.22 Loss 0.163966
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 3883 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2576/  2576, loss 0.158032 accuracy 98.25 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 97.94 Loss 0.176229
# Training statistics   at Epoch 10: Accuracy 98.25 Loss 0.158032
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 3520 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2576/  2576, loss 0.153110 accuracy 98.28 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.08 Loss 0.168073
# Training statistics   at Epoch 11: Accuracy 98.28 Loss 0.153110
# Time taken: 355 sec, Time/batch: 137 ms, Time remaining to train: 3195 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2576/  2576, loss 0.148753 accuracy 98.29 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.15 Loss 0.162431
# Training statistics   at Epoch 12: Accuracy 98.29 Loss 0.148753
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 2808 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2576/  2576, loss 0.144130 accuracy 98.33 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.09 Loss 0.160576
# Training statistics   at Epoch 13: Accuracy 98.33 Loss 0.144130
# Time taken: 354 sec, Time/batch: 137 ms, Time remaining to train: 2478 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2576/  2576, loss 0.140592 accuracy 98.33 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.09 Loss 0.157816
# Training statistics   at Epoch 14: Accuracy 98.33 Loss 0.140592
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 2118 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2576/  2576, loss 0.136686 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.09 Loss 0.156013
# Training statistics   at Epoch 15: Accuracy 98.35 Loss 0.136686
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 1750 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2576/  2576, loss 0.133632 accuracy 98.37 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.09 Loss 0.153411
# Training statistics   at Epoch 16: Accuracy 98.37 Loss 0.133632
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 1400 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2576/  2576, loss 0.130019 accuracy 98.39 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.09 Loss 0.152947
# Training statistics   at Epoch 17: Accuracy 98.39 Loss 0.130019
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 1050 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2576/  2576, loss 0.127439 accuracy 98.42 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.09 Loss 0.150258
# Training statistics   at Epoch 18: Accuracy 98.42 Loss 0.127439
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 704 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2576/  2576, loss 0.124228 accuracy 98.42 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.13 Loss 0.147260
# Training statistics   at Epoch 19: Accuracy 98.42 Loss 0.124228
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 350 sec
# Validation statistics after training: Accuracy 98.13 Loss 0.147260
# Training statistics after training: Accuracy 98.42 Loss 0.124228
# Outputting
# Evaluate
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Throughput:  100.0
# Accuracy  :  98.1300505050505
# Training for fold:  2
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k2.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k2.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k2.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k2.png
# Previus output:  None
# Found data for loading at  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2576/  2576, loss 0.886027 accuracy 84.39 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 91.09 Loss 0.593071
# Training statistics   at Epoch 0: Accuracy 84.39 Loss 0.886027
# Time taken: 384 sec, Time/batch: 149 ms, Time remaining to train: 7680 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2576/  2576, loss 0.392820 accuracy 95.69 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 82.09 Loss 0.805921
# Training statistics   at Epoch 1: Accuracy 95.69 Loss 0.392820
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 6650 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2576/  2576, loss 0.277907 accuracy 97.44 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.53 Loss 0.263622
# Training statistics   at Epoch 2: Accuracy 97.44 Loss 0.277907
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 6300 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2576/  2576, loss 0.247522 accuracy 97.63 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.21 Loss 0.257569
# Training statistics   at Epoch 3: Accuracy 97.63 Loss 0.247522
# Time taken: 348 sec, Time/batch: 135 ms, Time remaining to train: 5916 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2576/  2576, loss 0.224108 accuracy 97.77 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.74 Loss 0.220753
# Training statistics   at Epoch 4: Accuracy 97.77 Loss 0.224108
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 5584 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2576/  2576, loss 0.205797 accuracy 97.87 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.83 Loss 0.204174
# Training statistics   at Epoch 5: Accuracy 97.87 Loss 0.205797
# Time taken: 348 sec, Time/batch: 135 ms, Time remaining to train: 5220 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2576/  2576, loss 0.185613 accuracy 98.12 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 98.01 Loss 0.192175
# Training statistics   at Epoch 6: Accuracy 98.12 Loss 0.185613
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 4900 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2576/  2576, loss 0.177210 accuracy 98.18 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.06 Loss 0.185371
# Training statistics   at Epoch 7: Accuracy 98.18 Loss 0.177210
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 4537 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2576/  2576, loss 0.170472 accuracy 98.19 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 98.03 Loss 0.181134
# Training statistics   at Epoch 8: Accuracy 98.19 Loss 0.170472
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 4188 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2576/  2576, loss 0.164608 accuracy 98.24 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 98.01 Loss 0.176784
# Training statistics   at Epoch 9: Accuracy 98.24 Loss 0.164608
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 3850 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2576/  2576, loss 0.158962 accuracy 98.26 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 98.12 Loss 0.169563
# Training statistics   at Epoch 10: Accuracy 98.26 Loss 0.158962
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 3510 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2576/  2576, loss 0.153715 accuracy 98.30 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.11 Loss 0.168971
# Training statistics   at Epoch 11: Accuracy 98.30 Loss 0.153715
# Time taken: 347 sec, Time/batch: 134 ms, Time remaining to train: 3123 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2576/  2576, loss 0.148993 accuracy 98.31 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.17 Loss 0.161316
# Training statistics   at Epoch 12: Accuracy 98.31 Loss 0.148993
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 2792 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2576/  2576, loss 0.144994 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.15 Loss 0.160931
# Training statistics   at Epoch 13: Accuracy 98.35 Loss 0.144994
# Time taken: 348 sec, Time/batch: 135 ms, Time remaining to train: 2436 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2576/  2576, loss 0.141031 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.15 Loss 0.156965
# Training statistics   at Epoch 14: Accuracy 98.35 Loss 0.141031
# Time taken: 347 sec, Time/batch: 134 ms, Time remaining to train: 2082 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2576/  2576, loss 0.137361 accuracy 98.37 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.04 Loss 0.158716
# Training statistics   at Epoch 15: Accuracy 98.37 Loss 0.137361
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 1745 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2576/  2576, loss 0.133988 accuracy 98.38 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.09 Loss 0.153712
# Training statistics   at Epoch 16: Accuracy 98.38 Loss 0.133988
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 1400 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2576/  2576, loss 0.130936 accuracy 98.39 ETA: 0          secc
# Validation statistics at Epoch 17: Accuracy 98.08 Loss 0.154724
# Training statistics   at Epoch 17: Accuracy 98.39 Loss 0.130936
# Time taken: 345 sec, Time/batch: 133 ms, Time remaining to train: 1035 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2576/  2576, loss 0.127867 accuracy 98.42 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.07 Loss 0.152922
# Training statistics   at Epoch 18: Accuracy 98.42 Loss 0.127867
# Time taken: 345 sec, Time/batch: 133 ms, Time remaining to train: 690 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2576/  2576, loss 0.124723 accuracy 98.44 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.05 Loss 0.150857
# Training statistics   at Epoch 19: Accuracy 98.44 Loss 0.124723
# Time taken: 347 sec, Time/batch: 134 ms, Time remaining to train: 347 sec
# Validation statistics after training: Accuracy 98.05 Loss 0.150857
# Training statistics after training: Accuracy 98.44 Loss 0.124723
# Outputting
# Evaluate
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Throughput:  100.0
# Accuracy  :  98.04608585858587
# Training for fold:  3
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k3.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k3.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k3.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k3.png
# Previus output:  None
# Found data for loading at  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2576/  2576, loss 0.898255 accuracy 84.09 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 84.06 Loss 0.826890
# Training statistics   at Epoch 0: Accuracy 84.09 Loss 0.898255
# Time taken: 382 sec, Time/batch: 148 ms, Time remaining to train: 7640 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2576/  2576, loss 0.398058 accuracy 95.47 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 95.99 Loss 0.342630
# Training statistics   at Epoch 1: Accuracy 95.47 Loss 0.398058
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 6688 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2576/  2576, loss 0.280906 accuracy 97.34 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.25 Loss 0.275093
# Training statistics   at Epoch 2: Accuracy 97.34 Loss 0.280906
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 6300 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2576/  2576, loss 0.250500 accuracy 97.53 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.08 Loss 0.261542
# Training statistics   at Epoch 3: Accuracy 97.53 Loss 0.250500
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 5967 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2576/  2576, loss 0.227712 accuracy 97.66 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.66 Loss 0.222886
# Training statistics   at Epoch 4: Accuracy 97.66 Loss 0.227712
# Time taken: 349 sec, Time/batch: 135 ms, Time remaining to train: 5584 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2576/  2576, loss 0.208890 accuracy 97.80 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.34 Loss 0.220907
# Training statistics   at Epoch 5: Accuracy 97.80 Loss 0.208890
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 5295 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2576/  2576, loss 0.188891 accuracy 98.06 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 97.93 Loss 0.197317
# Training statistics   at Epoch 6: Accuracy 98.06 Loss 0.188891
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 4914 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2576/  2576, loss 0.180454 accuracy 98.10 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 97.94 Loss 0.190226
# Training statistics   at Epoch 7: Accuracy 98.10 Loss 0.180454
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 4563 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2576/  2576, loss 0.173322 accuracy 98.15 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 97.85 Loss 0.189518
# Training statistics   at Epoch 8: Accuracy 98.15 Loss 0.173322
# Time taken: 350 sec, Time/batch: 135 ms, Time remaining to train: 4200 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2576/  2576, loss 0.167305 accuracy 98.18 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 97.92 Loss 0.181971
# Training statistics   at Epoch 9: Accuracy 98.18 Loss 0.167305
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 3883 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2576/  2576, loss 0.161377 accuracy 98.21 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 97.89 Loss 0.178240
# Training statistics   at Epoch 10: Accuracy 98.21 Loss 0.161377
# Time taken: 352 sec, Time/batch: 136 ms, Time remaining to train: 3520 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2576/  2576, loss 0.156066 accuracy 98.24 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.01 Loss 0.172056
# Training statistics   at Epoch 11: Accuracy 98.24 Loss 0.156066
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 3177 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2576/  2576, loss 0.151695 accuracy 98.26 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.09 Loss 0.165420
# Training statistics   at Epoch 12: Accuracy 98.26 Loss 0.151695
# Time taken: 351 sec, Time/batch: 136 ms, Time remaining to train: 2808 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2576/  2576, loss 0.146936 accuracy 98.28 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.11 Loss 0.162226
# Training statistics   at Epoch 13: Accuracy 98.28 Loss 0.146936
# Time taken: 355 sec, Time/batch: 137 ms, Time remaining to train: 2485 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2576/  2576, loss 0.142982 accuracy 98.31 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.10 Loss 0.159653
# Training statistics   at Epoch 14: Accuracy 98.31 Loss 0.142982
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 2118 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2576/  2576, loss 0.139460 accuracy 98.32 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.08 Loss 0.159028
# Training statistics   at Epoch 15: Accuracy 98.32 Loss 0.139460
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 1780 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2576/  2576, loss 0.135907 accuracy 98.35 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 97.94 Loss 0.160329
# Training statistics   at Epoch 16: Accuracy 98.35 Loss 0.135907
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 1432 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2576/  2576, loss 0.132563 accuracy 98.36 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.12 Loss 0.153950
# Training statistics   at Epoch 17: Accuracy 98.36 Loss 0.132563
# Time taken: 355 sec, Time/batch: 137 ms, Time remaining to train: 1065 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2576/  2576, loss 0.130201 accuracy 98.37 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 97.80 Loss 0.161430
# Training statistics   at Epoch 18: Accuracy 98.37 Loss 0.130201
# Time taken: 357 sec, Time/batch: 138 ms, Time remaining to train: 714 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2576/  2576, loss 0.126435 accuracy 98.41 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 98.15 Loss 0.147232
# Training statistics   at Epoch 19: Accuracy 98.41 Loss 0.126435
# Time taken: 360 sec, Time/batch: 139 ms, Time remaining to train: 360 sec
# Validation statistics after training: Accuracy 98.15 Loss 0.147232
# Training statistics after training: Accuracy 98.41 Loss 0.126435
# Outputting
# Evaluate
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Throughput:  100.0
# Accuracy  :  98.1496212121212
# Training for fold:  4
# Doing scheme:  0
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  0
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k4.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k4.h5
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k4.csv
# Previus output:  None
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k4.png
# Previus output:  None
# Found data for loading at  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# /home/bhaskar/anaconda3/envs/soup/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Start training
#
# Start epoch 1/20 of training, Total Epoch: 1/60
# Batch   2576/  2576, loss 0.872893 accuracy 84.75 ETA: 0          sec
# Validation statistics at Epoch 0: Accuracy 93.27 Loss 0.512268
# Training statistics   at Epoch 0: Accuracy 84.75 Loss 0.872893
# Time taken: 401 sec, Time/batch: 155 ms, Time remaining to train: 8020 sec
# Start epoch 2/20 of training, Total Epoch: 2/60
# Batch   2576/  2576, loss 0.384333 accuracy 95.83 ETA: 0          sec
# Validation statistics at Epoch 1: Accuracy 82.68 Loss 0.793007
# Training statistics   at Epoch 1: Accuracy 95.83 Loss 0.384333
# Time taken: 366 sec, Time/batch: 142 ms, Time remaining to train: 6954 sec
# Start epoch 3/20 of training, Total Epoch: 3/60
# Batch   2576/  2576, loss 0.271801 accuracy 97.53 ETA: 0          sec
# Validation statistics at Epoch 2: Accuracy 97.60 Loss 0.263500
# Training statistics   at Epoch 2: Accuracy 97.53 Loss 0.271801
# Time taken: 365 sec, Time/batch: 141 ms, Time remaining to train: 6570 sec
# Start epoch 4/20 of training, Total Epoch: 4/60
# Batch   2576/  2576, loss 0.241465 accuracy 97.72 ETA: 0          sec
# Validation statistics at Epoch 3: Accuracy 97.69 Loss 0.237425
# Training statistics   at Epoch 3: Accuracy 97.72 Loss 0.241465
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 6086 sec
# Start epoch 5/20 of training, Total Epoch: 5/60
# Batch   2576/  2576, loss 0.218838 accuracy 97.83 ETA: 0          sec
# Validation statistics at Epoch 4: Accuracy 97.71 Loss 0.220904
# Training statistics   at Epoch 4: Accuracy 97.83 Loss 0.218838
# Time taken: 361 sec, Time/batch: 140 ms, Time remaining to train: 5776 sec
# Start epoch 6/20 of training, Total Epoch: 6/60
# Batch   2576/  2576, loss 0.201216 accuracy 97.93 ETA: 0          sec
# Validation statistics at Epoch 5: Accuracy 97.48 Loss 0.216807
# Training statistics   at Epoch 5: Accuracy 97.93 Loss 0.201216
# Time taken: 361 sec, Time/batch: 140 ms, Time remaining to train: 5415 sec
# Start epoch 7/20 of training, Total Epoch: 7/60
# Batch   2576/  2576, loss 0.181541 accuracy 98.17 ETA: 0          sec
# Validation statistics at Epoch 6: Accuracy 97.88 Loss 0.196661
# Training statistics   at Epoch 6: Accuracy 98.17 Loss 0.181541
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 5012 sec
# Start epoch 8/20 of training, Total Epoch: 8/60
# Batch   2576/  2576, loss 0.173679 accuracy 98.22 ETA: 0          sec
# Validation statistics at Epoch 7: Accuracy 98.10 Loss 0.182056
# Training statistics   at Epoch 7: Accuracy 98.22 Loss 0.173679
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 4628 sec
# Start epoch 9/20 of training, Total Epoch: 9/60
# Batch   2576/  2576, loss 0.166998 accuracy 98.25 ETA: 0          sec
# Validation statistics at Epoch 8: Accuracy 98.05 Loss 0.180652
# Training statistics   at Epoch 8: Accuracy 98.25 Loss 0.166998
# Time taken: 353 sec, Time/batch: 137 ms, Time remaining to train: 4236 sec
# Start epoch 10/20 of training, Total Epoch: 10/60
# Batch   2576/  2576, loss 0.160801 accuracy 98.28 ETA: 0          sec
# Validation statistics at Epoch 9: Accuracy 98.04 Loss 0.175990
# Training statistics   at Epoch 9: Accuracy 98.28 Loss 0.160801
# Time taken: 359 sec, Time/batch: 139 ms, Time remaining to train: 3949 sec
# Start epoch 11/20 of training, Total Epoch: 11/60
# Batch   2576/  2576, loss 0.156028 accuracy 98.29 ETA: 0          sec
# Validation statistics at Epoch 10: Accuracy 97.62 Loss 0.186127
# Training statistics   at Epoch 10: Accuracy 98.29 Loss 0.156028
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 3580 sec
# Start epoch 12/20 of training, Total Epoch: 12/60
# Batch   2576/  2576, loss 0.150688 accuracy 98.31 ETA: 0          sec
# Validation statistics at Epoch 11: Accuracy 98.07 Loss 0.167680
# Training statistics   at Epoch 11: Accuracy 98.31 Loss 0.150688
# Time taken: 359 sec, Time/batch: 139 ms, Time remaining to train: 3231 sec
# Start epoch 13/20 of training, Total Epoch: 13/60
# Batch   2576/  2576, loss 0.146043 accuracy 98.34 ETA: 0          sec
# Validation statistics at Epoch 12: Accuracy 98.06 Loss 0.165873
# Training statistics   at Epoch 12: Accuracy 98.34 Loss 0.146043
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 2864 sec
# Start epoch 14/20 of training, Total Epoch: 14/60
# Batch   2576/  2576, loss 0.142253 accuracy 98.36 ETA: 0          sec
# Validation statistics at Epoch 13: Accuracy 98.09 Loss 0.161965
# Training statistics   at Epoch 13: Accuracy 98.36 Loss 0.142253
# Time taken: 357 sec, Time/batch: 138 ms, Time remaining to train: 2499 sec
# Start epoch 15/20 of training, Total Epoch: 15/60
# Batch   2576/  2576, loss 0.138114 accuracy 98.37 ETA: 0          sec
# Validation statistics at Epoch 14: Accuracy 98.17 Loss 0.155984
# Training statistics   at Epoch 14: Accuracy 98.37 Loss 0.138114
# Time taken: 359 sec, Time/batch: 139 ms, Time remaining to train: 2154 sec
# Start epoch 16/20 of training, Total Epoch: 16/60
# Batch   2576/  2576, loss 0.134595 accuracy 98.41 ETA: 0          sec
# Validation statistics at Epoch 15: Accuracy 98.05 Loss 0.158951
# Training statistics   at Epoch 15: Accuracy 98.41 Loss 0.134595
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 1790 sec
# Start epoch 17/20 of training, Total Epoch: 17/60
# Batch   2576/  2576, loss 0.131625 accuracy 98.40 ETA: 0          sec
# Validation statistics at Epoch 16: Accuracy 98.04 Loss 0.156384
# Training statistics   at Epoch 16: Accuracy 98.40 Loss 0.131625
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 1432 sec
# Start epoch 18/20 of training, Total Epoch: 18/60
# Batch   2576/  2576, loss 0.128239 accuracy 98.43 ETA: 0          sec
# Validation statistics at Epoch 17: Accuracy 98.17 Loss 0.152517
# Training statistics   at Epoch 17: Accuracy 98.43 Loss 0.128239
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 1068 sec
# Start epoch 19/20 of training, Total Epoch: 19/60
# Batch   2576/  2576, loss 0.125758 accuracy 98.43 ETA: 0          sec
# Validation statistics at Epoch 18: Accuracy 98.13 Loss 0.149828
# Training statistics   at Epoch 18: Accuracy 98.43 Loss 0.125758
# Time taken: 358 sec, Time/batch: 138 ms, Time remaining to train: 716 sec
# Start epoch 20/20 of training, Total Epoch: 20/60
# Batch   2576/  2576, loss 0.123252 accuracy 98.45 ETA: 0          sec
# Validation statistics at Epoch 19: Accuracy 97.98 Loss 0.152459
# Training statistics   at Epoch 19: Accuracy 98.45 Loss 0.123252
# Time taken: 356 sec, Time/batch: 138 ms, Time remaining to train: 356 sec
# Validation statistics after training: Accuracy 97.98 Loss 0.152459
# Training statistics after training: Accuracy 98.45 Loss 0.123252
# Outputting
# Evaluate
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Throughput:  100.0
# Accuracy  :  97.9760101010101
# Datapath: /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Training for fold:  0
# Doing scheme:  1
# loading parameter from /home/bhaskar/work/tyCooNNTest/preprocess_setting.yaml
#
# setting output at iter:  1
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_v1_k0.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k0.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_v1_k0.h5
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//AllWt_k0.h5
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_v1_k0.csv
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k0.csv
# Output set:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_v1_k0.png
# Previus output:  /home/bhaskar/work/tyCooNNTest/train_temp_pf//history_k0.png
# Loading data from  /home/bhaskar/work/tyCooNNTest/train_temp_pf//data.pkl
# Building network
# Setting optim and batch size
# Setting loss function
# Compile model and load pretrain (opt)
# Loaded pretrained model weights from /home/bhaskar/work/tyCooNNTest/train_temp_pf//BestWt_k0.h5
# Setting checkpointers
# Start fitting
# test_x shape: (158400, 8192, 1)
# test_y shape: (158400, 44)
# train_x shape: (633600, 8192, 1)
# train_y shape: (633600, 44)
# Num Sample: 633600 Num Sample Aug: 1900800 Num Batch: 7727
# fitting with augmentation with 7727 batches
# ## Dummy ##
# n_cores 10
# data augmentation: Start ██████████████████████████████████████████████████ end
# end merge
# ## Dummy End ##
# Process Process-6:
# Traceback (most recent call last):
#   File "/home/bhaskar/anaconda3/envs/soup/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/bhaskar/anaconda3/envs/soup/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "../training/Trainning.py", line 861, in wrapper_func
#     queue.put(func(*args,**kwargs))
#   File "../training/Trainning.py", line 844, in do_train
#     T.fit(filter_index = eids, apply_post_filter_to_train=apply_post_filter_to_train)
#   File "../training/Trainning.py", line 656, in fit
#     tt = (self.test_time_per_sample * len(self.X_test)) / 1000
# TypeError: object of type 'NoneType' has no len()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_85672/2063177835.py in <module>
# ----> 1 training.do_train_by_scheme(inputDir,outputDir,params,scheme)
#
# ~/work/tyCooNN_2201/training/Trainning.py in do_train_by_scheme(indir, outdir, paramPath, scheme)
#     914                 scheme[sk[iteration]]['k'] = k
#     915                 print("Training for fold: ",k)
# --> 916                 datapath, eids, test_time_per_sample,wlen, num_classes = process_run(do_train,indir,outdir,paramPath,iteration,**scheme[sk[iteration]])
#     917         else:
#     918             datapath,eids,test_time_per_sample,wlen, num_classes = process_run(do_train,indir,outdir,paramPath,iteration,**scheme[sk[iteration]])
#
# ~/work/tyCooNN_2201/training/Trainning.py in process_run(func, *args, **kwargs)
#     869         return result
#     870
# --> 871     return process(*args,**kwargs)
#     872
#     873 def do_train_by_scheme(indir,outdir,paramPath,scheme):
#
# ~/work/tyCooNN_2201/training/Trainning.py in process(*args, **kwargs)
#     865         p = Process(target = wrapper_func, args = [queue] + list(args), kwargs = kwargs)
#     866         p.start()
# --> 867         result = queue.get()
#     868         p.join()
#     869         return result
#
# ~/anaconda3/envs/soup/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# ~/anaconda3/envs/soup/lib/python3.7/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# ~/anaconda3/envs/soup/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/envs/soup/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
