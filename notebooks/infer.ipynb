# %%
import os
import sys
sys.path.append("../")
import inference.Inference as inference

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
indir  = "/share/trna/testdata/210213_ecoli_WT_total_LB_BW_log_1_V7/1/20210213_1049_MN23375_FAO46570_a665fb8a/fast5/workspace"
outdir = "/share/bhaskar/tyCooNNTest/train/"

outpath = "/share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7"
fasta = "/share/bhaskar/tyCooNNTest/fasta/ecolitRNA_full.fa"
paramPath = "/share/bhaskar/tyCooNNTest/preprocess_setting.yaml"

# %%
inference.evaluate(paramPath,indir,outdir,outpath,fasta,"S")
# Out:
# loading parameter from /share/bhaskar/tyCooNNTest/preprocess_setting.yaml
#
# trna ['ala1', 'ala2', 'arg2', 'arg3', 'arg4', 'arg5', 'asn', 'asp', 'cys', 'fmet', 'gln1', 'gln2', 'glu', 'gly1', 'gly2', 'gly3', 'his', 'ile1', 'ile2', 'leu1', 'leu2', 'leu3', 'leu4', 'leu5', 'lys', 'met', 'phe', 'pro1', 'pro2', 'pro3', 'sec', 'ser1', 'ser2', 'ser3', 'ser5', 'thr1', 'thr2', 'thr3', 'thr4', 'trp', 'tyr', 'val1', 'val2a', 'val2b']
# 3564
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 1
# doing..1/28
# 3553
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 2
# doing..2/28
# 3548
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 3
# doing..3/28
# 3540
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 4
# doing..4/28
# 3545
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 5
# doing..5/28
# 3514
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 6
# doing..6/28
# 3513
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 7
# doing..7/28
# 3542
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 8
# doing..8/28
# 3508
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 9
# doing..9/28
# 3509
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 10
# doing..10/28
# 3467
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 11
# doing..11/28
# 3503
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 12
# doing..12/28
# 3547
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 13
# doing..13/28
# 3447
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 14
# doing..14/28
# 3464
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 15
# doing..15/28
# 3414
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 16
# doing..16/28
# 3336
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 17
# doing..17/28
# 3266
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 18
# doing..18/28
# 3293
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 19
# doing..19/28
# 3238
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 20
# doing..20/28
# 2710
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 21
# doing..21/28
# 3529
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 22
# doing..22/28
# 3537
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 23
# doing..23/28
# 3516
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 24
# doing..24/28
# 3540
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 25
# doing..25/28
# 3505
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 26
# doing..26/28
# 3564
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 27
# doing..27/28
# 3516
# print single5 output to /share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/single_fast5 28
# doing..28/28

# %%
import pandas as pd

# %%
d = pd.read_csv("/share/bhaskar/tyCooNNTest/WT_total_LB_BW_log_1_V7/count.csv").T

# %%
d = d.iloc[1:,:]
d
# Out:
#             0        1
# ala1   3943.0  17389.0
# ala2   1675.0   1924.0
# arg2   3623.0   4116.0
# arg3    386.0    414.0
# arg4    444.0    504.0
# arg5     99.0    189.0
# asn    2823.0   2859.0
# asp    4419.0   4515.0
# cys    1160.0   1218.0
# fmet   2342.0   2423.0
# gln1   2381.0   2454.0
# gln2   2916.0   3159.0
# glu    9955.0  10006.0
# gly1    424.0    482.0
# gly2   1258.0   1447.0
# gly3   6979.0   7113.0
# his    1833.0   1905.0
# ile1   2132.0   2243.0
# ile2    180.0    268.0
# leu1   6056.0   6355.0
# leu2   1262.0   1313.0
# leu3    506.0    944.0
# leu4    854.0    941.0
# leu5    799.0    813.0
# lys    3464.0   3540.0
# met    1031.0   1115.0
# phe    3050.0   3790.0
# pro1   1771.0   1880.0
# pro2    726.0    759.0
# pro3   2819.0   2898.0
# sec     138.0    228.0
# ser1    932.0   1037.0
# ser2    137.0    181.0
# ser3   1908.0   2034.0
# ser5   1130.0   1163.0
# thr1   1194.0   1312.0
# thr2    583.0   1110.0
# thr3    661.0    715.0
# thr4   1203.0   1659.0
# trp    3772.0   3828.0
# tyr    4370.0   4454.0
# val1   1803.0   1968.0
# val2a   584.0    681.0
# val2b   492.0    606.0

# %%
passCount = d[0]
allCount = d[1]

# %%
names = d.index

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(21,5))
plt.bar(list(range(44)),passCount)
plt.xticks(list(range(44)),names,rotation=90,size=20)
plt.yticks(size=20)
plt.ylim(0,17500)
plt.show()

# %%
plt.figure(figsize=(21,5))
plt.bar(list(range(44)),allCount)
plt.xticks(list(range(44)),names,rotation=90,size=20)
plt.yticks(size=20)
plt.show()
